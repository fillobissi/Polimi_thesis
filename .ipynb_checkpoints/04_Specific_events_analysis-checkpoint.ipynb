# %% [markdown]
# ## 04 - SPECIFIC EVENTS ANALYSIS
#
# ###### At this stage we will select some specific heat waves events and we will go to study them deeply employing the heat stress indices

# %% [markdown]
# #### 04.1 - Data connection

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xarray as xr

# Caricamento CSV
df = pd.read_csv(r"C:\Users\andre\OneDrive - Politecnico di Milano\Tesi_di_laurea\elab\04_Outputs\heatstress_all_timestamps_all_years.csv", parse_dates=["Timestamp"])

# Aggiunta della colonna data pura
df["Date"] = df["Timestamp"].dt.date
df["Hour"] = df["Timestamp"].dt.hour

df.head(10)
# Out:
#             Timestamp  Numero Timestamp                    Indice  Media (°C)  \
# 0 1981-01-01 11:00:00                 1                Heat Index   62.587902
# 1 1981-01-01 11:00:00                 1                   Humidex   -0.210730
# 2 1981-01-01 11:00:00                 1  Lethal Heat Stress Index    6.230457
# 3 1981-01-01 11:00:00                 1                      UTCI    3.051339
# 4 1981-01-01 11:00:00                 1                      WBGT    0.597468
# 5 1981-01-01 11:00:00                 1         Relative Humidity   65.170662
# 6 1981-01-01 12:00:00                 2                Heat Index   60.900555
# 7 1981-01-01 12:00:00                 2                   Humidex    0.419754
# 8 1981-01-01 12:00:00                 2  Lethal Heat Stress Index    6.424790
# 9 1981-01-01 12:00:00                 2                      UTCI    3.618221
#
#    Mediana (°C)  95° Perc. (°C)  99° Perc. (°C)  Massimo (°C)  Soglia (°C)  \
# 0     56.702271      123.101692      145.308289    187.422272         40.6
# 1      0.389642        7.040080        8.284530     10.507238         45.0
# 2      6.795696       12.046806       13.309931     15.195611         27.0
# 3      3.638378        9.336108       10.814054     13.287813         46.0
# 4      1.160547        6.130822        6.918025      8.408998         30.0
# 5     66.382080       89.112541       96.809364     99.193085         80.0
# 6     53.021690      128.115738      151.487961    191.071991         40.6
# 7      1.534759        8.129251        9.231105     11.290494         45.0
# 8      7.170904       12.713841       13.531538     14.955934         27.0
# 9      4.627268       10.325649       11.570192     14.065192         46.0
#
#   Media > Soglia Mediana > Soglia 95° Perc. > Soglia 99° Perc. > Soglia  \
# 0             si               si                 si                 si
# 1             no               no                 no                 no
# 2             no               no                 no                 no
# 3             no               no                 no                 no
# 4             no               no                 no                 no
# 5             no               no                 si                 si
# 6             si               si                 si                 si
# 7             no               no                 no                 no
# 8             no               no                 no                 no
# 9             no               no                 no                 no
#
#   Massimo > Soglia        Data        Date  Hour
# 0               si  1981-01-01  1981-01-01    11
# 1               no  1981-01-01  1981-01-01    11
# 2               no  1981-01-01  1981-01-01    11
# 3               no  1981-01-01  1981-01-01    11
# 4               no  1981-01-01  1981-01-01    11
# 5               si  1981-01-01  1981-01-01    11
# 6               si  1981-01-01  1981-01-01    12
# 7               no  1981-01-01  1981-01-01    12
# 8               no  1981-01-01  1981-01-01    12
# 9               no  1981-01-01  1981-01-01    12

# %% [markdown]
# #### 04.2 - Selection of specific heat wave events and extraction of the warmest day and hours
#
# ##### first event selected
# star date     2017-08-01
#
# end date      2017-08-05
#
# ##### second event selected
# star date     2023-08-19
#
# end date      2023-08-25

# %%
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from IPython.display import display, HTML
from pandas.plotting import table

# === CONFIG ===
path_nc = r"C:\Users\andre\OneDrive\Desktop\Datasets_Geoinfprj\Enlarged_datasets\2m_air_temp\air_temperature_era5-81_23.nc"
heatwave_1_dates = pd.date_range("2017-08-01", "2017-08-05")
target_hours = list(range(11, 18))  # 11–17

# === LOAD DATA ===
ds = xr.open_dataset(path_nc)
ds["time"] = pd.to_datetime(ds["time"].values)

# === COMPUTE STATISTICS FUNCTION ===
def compute_stats(df_dates):
    rows = []
    for date in df_dates:
        for hour in target_hours:
            mask = (ds["time"].dt.floor("D") == date) & (ds["time"].dt.hour == hour)
            data = ds["T_2M"].sel(time=mask)
            values = data.values.flatten()
            values = values[~np.isnan(values)]

            if len(values) > 0:
                rows.append({
                    "Day": date.strftime("%y-%m-%d"),
                    "Hour": f"{hour:02d}:00",
                    "Temp Mean": np.mean(values) - 273.15,
                    "Temp Median": np.median(values) - 273.15,
                    "Temp 95th Perc": np.percentile(values, 95) - 273.15,
                    "Temp 99th Perc": np.percentile(values, 99) - 273.15,
                    "Temp Max": np.max(values) - 273.15,
                })
    return pd.DataFrame(rows)

df_hw1 = compute_stats(heatwave_1_dates)

# === COLOR STYLING ===
def style_heatmap(df):
    styles = pd.DataFrame("", index=df.index, columns=df.columns)
    for col in df.columns:
        if col not in ["Day", "Hour"]:
            vals = df[col]
            normed = (vals - vals.min()) / (vals.max() - vals.min())
            colors = normed.map(lambda x: mcolors.to_hex(plt.cm.YlOrRd(x if not np.isnan(x) else 0)))
            max_val = vals.max()
            for i in vals.index:
                font = "white" if vals[i] == max_val else "black"
                styles.loc[i, col] = f"background-color: {colors[i]}; color: {font};"

    return df.style\
        .apply(lambda _: styles, axis=None)\
        .format("{:.2f}", subset=df.select_dtypes(include=[np.number]).columns, na_rep="-")\
        .set_table_styles([
            {'selector': 'th', 'props': [('font-size', '10pt')]},
            {'selector': 'td', 'props': [('font-size', '10pt'), ('padding', '3px')]}
        ])\
        .hide(axis="index")

# === EXPORT TO PNG ===
def export_table_as_image(df, filename, title=None):
    fig, ax = plt.subplots(figsize=(df.shape[1]*1.2, df.shape[0]*0.4))
    ax.axis("off")
    if title:
        plt.title(title, fontsize=14, pad=20)
    table(ax, df.round(2), loc='center', cellLoc='center', colWidths=[0.15]*len(df.columns))
    plt.tight_layout()
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close()

# === DISPLAY AND EXPORT ===
styled_hw1 = style_heatmap(df_hw1)
display(HTML("<h3>Heatwave 01–05 August 2017</h3>"))
display(styled_hw1)

export_table_as_image(
    df_hw1.drop(columns=["Day", "Hour"]),
    r"C:\Users\andre\OneDrive - Politecnico di Milano\Tesi_di_laurea\elab\04_Outputs\heatwave_Aug_2017_table.png",
    title="Heatwave Aug 2017"
)
# Out:
# <h3>Heatwave 01–05 August 2017</h3>
# <style type="text/css">
# #T_dcb70 th {
#   font-size: 10pt;
# }
# #T_dcb70 td {
#   font-size: 10pt;
#   padding: 3px;
# }
# #T_dcb70_row0_col2, #T_dcb70_row0_col3, #T_dcb70_row0_col4, #T_dcb70_row0_col5, #T_dcb70_row0_col6 {
#   background-color: #ffffcc;
#   color: black;
# }
# #T_dcb70_row1_col2 {
#   background-color: #fec965;
#   color: black;
# }
# #T_dcb70_row1_col3 {
#   background-color: #fec05b;
#   color: black;
# }
# #T_dcb70_row1_col4 {
#   background-color: #feb852;
#   color: black;
# }
# #T_dcb70_row1_col5 {
#   background-color: #feb44e;
#   color: black;
# }
# #T_dcb70_row1_col6 {
#   background-color: #fea145;
#   color: black;
# }
# #T_dcb70_row2_col2, #T_dcb70_row13_col5 {
#   background-color: #fd8239;
#   color: black;
# }
# #T_dcb70_row2_col3, #T_dcb70_row13_col6 {
#   background-color: #fd7636;
#   color: black;
# }
# #T_dcb70_row2_col4, #T_dcb70_row4_col2, #T_dcb70_row19_col3 {
#   background-color: #fc4f2a;
#   color: black;
# }
# #T_dcb70_row2_col5, #T_dcb70_row26_col6, #T_dcb70_row30_col5 {
#   background-color: #f43e26;
#   color: black;
# }
# #T_dcb70_row2_col6, #T_dcb70_row30_col3 {
#   background-color: #ef3323;
#   color: black;
# }
# #T_dcb70_row3_col2, #T_dcb70_row26_col2 {
#   background-color: #fb4b29;
#   color: black;
# }
# #T_dcb70_row3_col3 {
#   background-color: #f13624;
#   color: black;
# }
# #T_dcb70_row3_col4 {
#   background-color: #e0181d;
#   color: black;
# }
# #T_dcb70_row3_col5, #T_dcb70_row25_col6 {
#   background-color: #d41020;
#   color: black;
# }
# #T_dcb70_row3_col6 {
#   background-color: #d51020;
#   color: black;
# }
# #T_dcb70_row4_col3, #T_dcb70_row20_col6, #T_dcb70_row33_col4 {
#   background-color: #f43d25;
#   color: black;
# }
# #T_dcb70_row4_col4, #T_dcb70_row32_col5 {
#   background-color: #dd161d;
#   color: black;
# }
# #T_dcb70_row4_col5, #T_dcb70_row10_col5 {
#   background-color: #cf0c21;
#   color: black;
# }
# #T_dcb70_row4_col6 {
#   background-color: #cb0a22;
#   color: black;
# }
# #T_dcb70_row5_col2, #T_dcb70_row5_col3 {
#   background-color: #fd953f;
#   color: black;
# }
# #T_dcb70_row5_col4 {
#   background-color: #f64227;
#   color: black;
# }
# #T_dcb70_row5_col5 {
#   background-color: #eb2b21;
#   color: black;
# }
# #T_dcb70_row5_col6, #T_dcb70_row26_col5 {
#   background-color: #ed2e21;
#   color: black;
# }
# #T_dcb70_row6_col2, #T_dcb70_row27_col3 {
#   background-color: #ffe793;
#   color: black;
# }
# #T_dcb70_row6_col3 {
#   background-color: #ffe895;
#   color: black;
# }
# #T_dcb70_row6_col4, #T_dcb70_row6_col6, #T_dcb70_row20_col2 {
#   background-color: #fea647;
#   color: black;
# }
# #T_dcb70_row6_col5 {
#   background-color: #fd9d43;
#   color: black;
# }
# #T_dcb70_row7_col2, #T_dcb70_row7_col4 {
#   background-color: #fed16e;
#   color: black;
# }
# #T_dcb70_row7_col3 {
#   background-color: #febe59;
#   color: black;
# }
# #T_dcb70_row7_col5 {
#   background-color: #fec35e;
#   color: black;
# }
# #T_dcb70_row7_col6 {
#   background-color: #feb651;
#   color: black;
# }
# #T_dcb70_row8_col2 {
#   background-color: #fd8038;
#   color: black;
# }
# #T_dcb70_row8_col3 {
#   background-color: #fc612f;
#   color: black;
# }
# #T_dcb70_row8_col4, #T_dcb70_row22_col4 {
#   background-color: #fd8c3c;
#   color: black;
# }
# #T_dcb70_row8_col5, #T_dcb70_row22_col5 {
#   background-color: #fd7e38;
#   color: black;
# }
# #T_dcb70_row8_col6 {
#   background-color: #fc6a32;
#   color: black;
# }
# #T_dcb70_row9_col2, #T_dcb70_row9_col4 {
#   background-color: #ed3022;
#   color: black;
# }
# #T_dcb70_row9_col3 {
#   background-color: #e51e1d;
#   color: black;
# }
# #T_dcb70_row9_col5 {
#   background-color: #ea2920;
#   color: black;
# }
# #T_dcb70_row9_col6, #T_dcb70_row22_col2, #T_dcb70_row22_col3 {
#   background-color: #e8241f;
#   color: black;
# }
# #T_dcb70_row10_col2 {
#   background-color: #dc151e;
#   color: black;
# }
# #T_dcb70_row10_col3, #T_dcb70_row32_col4 {
#   background-color: #e1191d;
#   color: black;
# }
# #T_dcb70_row10_col4 {
#   background-color: #cd0b22;
#   color: black;
# }
# #T_dcb70_row10_col6 {
#   background-color: #ca0923;
#   color: black;
# }
# #T_dcb70_row11_col2 {
#   background-color: #e7231e;
#   color: black;
# }
# #T_dcb70_row11_col3 {
#   background-color: #f54026;
#   color: black;
# }
# #T_dcb70_row11_col4, #T_dcb70_row25_col5 {
#   background-color: #c50624;
#   color: black;
# }
# #T_dcb70_row11_col5 {
#   background-color: #c80723;
#   color: black;
# }
# #T_dcb70_row11_col6, #T_dcb70_row19_col6 {
#   background-color: #c70723;
#   color: black;
# }
# #T_dcb70_row12_col2 {
#   background-color: #fd6e33;
#   color: black;
# }
# #T_dcb70_row12_col3, #T_dcb70_row34_col4 {
#   background-color: #fd9740;
#   color: black;
# }
# #T_dcb70_row12_col4, #T_dcb70_row12_col5, #T_dcb70_row15_col3 {
#   background-color: #e31a1c;
#   color: black;
# }
# #T_dcb70_row12_col6 {
#   background-color: #db141e;
#   color: black;
# }
# #T_dcb70_row13_col2, #T_dcb70_row14_col4 {
#   background-color: #feda78;
#   color: black;
# }
# #T_dcb70_row13_col3 {
#   background-color: #ffeda1;
#   color: black;
# }
# #T_dcb70_row13_col4 {
#   background-color: #fd863a;
#   color: black;
# }
# #T_dcb70_row14_col2 {
#   background-color: #fea044;
#   color: black;
# }
# #T_dcb70_row14_col3, #T_dcb70_row21_col2 {
#   background-color: #fd9640;
#   color: black;
# }
# #T_dcb70_row14_col5 {
#   background-color: #fed673;
#   color: black;
# }
# #T_dcb70_row14_col6 {
#   background-color: #fec863;
#   color: black;
# }
# #T_dcb70_row15_col2, #T_dcb70_row19_col2, #T_dcb70_row23_col4, #T_dcb70_row23_col5, #T_dcb70_row30_col6, #T_dcb70_row31_col3 {
#   background-color: #e6211e;
#   color: black;
# }
# #T_dcb70_row15_col4 {
#   background-color: #fc572c;
#   color: black;
# }
# #T_dcb70_row15_col5 {
#   background-color: #fc592d;
#   color: black;
# }
# #T_dcb70_row15_col6, #T_dcb70_row32_col3 {
#   background-color: #f13824;
#   color: black;
# }
# #T_dcb70_row16_col2 {
#   background-color: #9f0026;
#   color: black;
# }
# #T_dcb70_row16_col3 {
#   background-color: #a10026;
#   color: black;
# }
# #T_dcb70_row16_col4 {
#   background-color: #c00225;
#   color: black;
# }
# #T_dcb70_row16_col5 {
#   background-color: #c10325;
#   color: black;
# }
# #T_dcb70_row16_col6, #T_dcb70_row23_col2 {
#   background-color: #ae0026;
#   color: black;
# }
# #T_dcb70_row17_col2, #T_dcb70_row17_col3, #T_dcb70_row17_col4, #T_dcb70_row18_col5, #T_dcb70_row18_col6 {
#   background-color: #800026;
#   color: white;
# }
# #T_dcb70_row17_col5 {
#   background-color: #840026;
#   color: black;
# }
# #T_dcb70_row17_col6, #T_dcb70_row18_col4 {
#   background-color: #800026;
#   color: black;
# }
# #T_dcb70_row18_col2 {
#   background-color: #a20026;
#   color: black;
# }
# #T_dcb70_row18_col3 {
#   background-color: #b70026;
#   color: black;
# }
# #T_dcb70_row19_col4, #T_dcb70_row24_col6 {
#   background-color: #ac0026;
#   color: black;
# }
# #T_dcb70_row19_col5 {
#   background-color: #b60026;
#   color: black;
# }
# #T_dcb70_row20_col3 {
#   background-color: #fece6a;
#   color: black;
# }
# #T_dcb70_row20_col4, #T_dcb70_row20_col5, #T_dcb70_row31_col2 {
#   background-color: #ec2c21;
#   color: black;
# }
# #T_dcb70_row21_col3 {
#   background-color: #fd903d;
#   color: black;
# }
# #T_dcb70_row21_col4 {
#   background-color: #fee085;
#   color: black;
# }
# #T_dcb70_row21_col5, #T_dcb70_row28_col3 {
#   background-color: #fed572;
#   color: black;
# }
# #T_dcb70_row21_col6 {
#   background-color: #fecf6b;
#   color: black;
# }
# #T_dcb70_row22_col6 {
#   background-color: #fc5d2e;
#   color: black;
# }
# #T_dcb70_row23_col3 {
#   background-color: #b00026;
#   color: black;
# }
# #T_dcb70_row23_col6 {
#   background-color: #e2191c;
#   color: black;
# }
# #T_dcb70_row24_col2 {
#   background-color: #8d0026;
#   color: black;
# }
# #T_dcb70_row24_col3 {
#   background-color: #9d0026;
#   color: black;
# }
# #T_dcb70_row24_col4 {
#   background-color: #bd0026;
#   color: black;
# }
# #T_dcb70_row24_col5 {
#   background-color: #c40524;
#   color: black;
# }
# #T_dcb70_row25_col2, #T_dcb70_row25_col4 {
#   background-color: #bb0026;
#   color: black;
# }
# #T_dcb70_row25_col3 {
#   background-color: #c90823;
#   color: black;
# }
# #T_dcb70_row26_col3 {
#   background-color: #fc6430;
#   color: black;
# }
# #T_dcb70_row26_col4 {
#   background-color: #e61f1d;
#   color: black;
# }
# #T_dcb70_row27_col2 {
#   background-color: #fedb7a;
#   color: black;
# }
# #T_dcb70_row27_col4, #T_dcb70_row29_col2 {
#   background-color: #fd9841;
#   color: black;
# }
# #T_dcb70_row27_col5, #T_dcb70_row33_col3 {
#   background-color: #fd8e3c;
#   color: black;
# }
# #T_dcb70_row27_col6, #T_dcb70_row33_col2 {
#   background-color: #fd9e43;
#   color: black;
# }
# #T

# %%
# === CONFIG ===
heatwave_2_dates = pd.date_range("2023-08-19", "2023-08-25")

# === CALCOLA ===
df_hw2 = compute_stats(heatwave_2_dates)

# === STILE E ESPORTAZIONE ===
styled_hw2 = style_heatmap(df_hw2)
display(HTML("<h3>Heatwave 19–25 August 2023</h3>"))
display(styled_hw2)

export_table_as_image(
    df_hw2.drop(columns=["Day", "Hour"]),
    r"C:\Users\andre\OneDrive - Politecnico di Milano\Tesi_di_laurea\elab\04_Outputs\heatwave_Aug_2023_table.png",
    title="Heatwave Aug 2023"
)
# Out:
# <h3>Heatwave 19–25 August 2023</h3>
# <style type="text/css">
# #T_696ee th {
#   font-size: 10pt;
# }
# #T_696ee td {
#   font-size: 10pt;
#   padding: 3px;
# }
# #T_696ee_row0_col2 {
#   background-color: #ffec9f;
#   color: black;
# }
# #T_696ee_row0_col3 {
#   background-color: #fedf83;
#   color: black;
# }
# #T_696ee_row0_col4, #T_696ee_row0_col5, #T_696ee_row0_col6, #T_696ee_row48_col2, #T_696ee_row48_col3 {
#   background-color: #ffffcc;
#   color: black;
# }
# #T_696ee_row1_col2, #T_696ee_row8_col5 {
#   background-color: #febb56;
#   color: black;
# }
# #T_696ee_row1_col3, #T_696ee_row14_col3, #T_696ee_row48_col6 {
#   background-color: #fea647;
#   color: black;
# }
# #T_696ee_row1_col4 {
#   background-color: #fed976;
#   color: black;
# }
# #T_696ee_row1_col5 {
#   background-color: #fed36f;
#   color: black;
# }
# #T_696ee_row1_col6 {
#   background-color: #fede82;
#   color: black;
# }
# #T_696ee_row2_col2 {
#   background-color: #fd8c3c;
#   color: black;
# }
# #T_696ee_row2_col3, #T_696ee_row21_col3 {
#   background-color: #fc6c33;
#   color: black;
# }
# #T_696ee_row2_col4, #T_696ee_row48_col4 {
#   background-color: #fd9a42;
#   color: black;
# }
# #T_696ee_row2_col5, #T_696ee_row12_col2, #T_696ee_row15_col4, #T_696ee_row20_col5 {
#   background-color: #fd9841;
#   color: black;
# }
# #T_696ee_row2_col6, #T_696ee_row6_col4, #T_696ee_row6_col5 {
#   background-color: #fd9f44;
#   color: black;
# }
# #T_696ee_row3_col2, #T_696ee_row27_col6, #T_696ee_row41_col6, #T_696ee_row43_col6 {
#   background-color: #fc6631;
#   color: black;
# }
# #T_696ee_row3_col3, #T_696ee_row4_col5 {
#   background-color: #fc4d2a;
#   color: black;
# }
# #T_696ee_row3_col4, #T_696ee_row19_col6 {
#   background-color: #fc6330;
#   color: black;
# }
# #T_696ee_row3_col5, #T_696ee_row4_col6, #T_696ee_row43_col3, #T_696ee_row47_col6 {
#   background-color: #fc5f2f;
#   color: black;
# }
# #T_696ee_row3_col6, #T_696ee_row9_col2, #T_696ee_row43_col4 {
#   background-color: #fd7836;
#   color: black;
# }
# #T_696ee_row4_col2, #T_696ee_row5_col5, #T_696ee_row28_col4 {
#   background-color: #fd7034;
#   color: black;
# }
# #T_696ee_row4_col3, #T_696ee_row19_col4, #T_696ee_row46_col2 {
#   background-color: #fc4f2a;
#   color: black;
# }
# #T_696ee_row4_col4, #T_696ee_row9_col6, #T_696ee_row11_col5, #T_696ee_row16_col4 {
#   background-color: #fc512b;
#   color: black;
# }
# #T_696ee_row5_col2 {
#   background-color: #fd9d43;
#   color: black;
# }
# #T_696ee_row5_col3, #T_696ee_row9_col5 {
#   background-color: #fd8038;
#   color: black;
# }
# #T_696ee_row5_col4, #T_696ee_row12_col6, #T_696ee_row20_col3 {
#   background-color: #fd6e33;
#   color: black;
# }
# #T_696ee_row5_col6, #T_696ee_row20_col2 {
#   background-color: #fd923e;
#   color: black;
# }
# #T_696ee_row6_col2 {
#   background-color: #fed977;
#   color: black;
# }
# #T_696ee_row6_col3, #T_696ee_row8_col6, #T_696ee_row20_col6 {
#   background-color: #feb24c;
#   color: black;
# }
# #T_696ee_row6_col6 {
#   background-color: #feb651;
#   color: black;
# }
# #T_696ee_row7_col2 {
#   background-color: #fee187;
#   color: black;
# }
# #T_696ee_row7_col3 {
#   background-color: #fed16e;
#   color: black;
# }
# #T_696ee_row7_col4 {
#   background-color: #fff8bb;
#   color: black;
# }
# #T_696ee_row7_col5 {
#   background-color: #fff0a8;
#   color: black;
# }
# #T_696ee_row7_col6 {
#   background-color: #fff3af;
#   color: black;
# }
# #T_696ee_row8_col2, #T_696ee_row14_col2, #T_696ee_row47_col2 {
#   background-color: #feac49;
#   color: black;
# }
# #T_696ee_row8_col3, #T_696ee_row42_col3 {
#   background-color: #fd9e43;
#   color: black;
# }
# #T_696ee_row8_col4 {
#   background-color: #fecc68;
#   color: black;
# }
# #T_696ee_row9_col3, #T_696ee_row34_col3, #T_696ee_row43_col2, #T_696ee_row43_col5 {
#   background-color: #fc6832;
#   color: black;
# }
# #T_696ee_row9_col4, #T_696ee_row20_col4 {
#   background-color: #fd9740;
#   color: black;
# }
# #T_696ee_row10_col2 {
#   background-color: #fc552c;
#   color: black;
# }
# #T_696ee_row10_col3, #T_696ee_row11_col3 {
#   background-color: #f84628;
#   color: black;
# }
# #T_696ee_row10_col4, #T_696ee_row21_col2, #T_696ee_row35_col2 {
#   background-color: #fc6a32;
#   color: black;
# }
# #T_696ee_row10_col5, #T_696ee_row19_col5 {
#   background-color: #fb4b29;
#   color: black;
# }
# #T_696ee_row10_col6, #T_696ee_row16_col3, #T_696ee_row26_col2 {
#   background-color: #e6211e;
#   color: black;
# }
# #T_696ee_row11_col2 {
#   background-color: #fc612f;
#   color: black;
# }
# #T_696ee_row11_col4 {
#   background-color: #fc6430;
#   color: black;
# }
# #T_696ee_row11_col6, #T_696ee_row19_col3, #T_696ee_row40_col3, #T_696ee_row45_col2 {
#   background-color: #e9261f;
#   color: black;
# }
# #T_696ee_row12_col3 {
#   background-color: #fd7234;
#   color: black;
# }
# #T_696ee_row12_col4 {
#   background-color: #fd8f3d;
#   color: black;
# }
# #T_696ee_row12_col5, #T_696ee_row28_col5 {
#   background-color: #fd7c37;
#   color: black;
# }
# #T_696ee_row13_col2 {
#   background-color: #fed774;
#   color: black;
# }
# #T_696ee_row13_col3, #T_696ee_row21_col4 {
#   background-color: #fead4a;
#   color: black;
# }
# #T_696ee_row13_col4 {
#   background-color: #febd57;
#   color: black;
# }
# #T_696ee_row13_col5 {
#   background-color: #feaf4b;
#   color: black;
# }
# #T_696ee_row13_col6, #T_696ee_row42_col5 {
#   background-color: #fec561;
#   color: black;
# }
# #T_696ee_row14_col4 {
#   background-color: #fed572;
#   color: black;
# }
# #T_696ee_row14_col5, #T_696ee_row42_col6 {
#   background-color: #fecb67;
#   color: black;
# }
# #T_696ee_row14_col6 {
#   background-color: #feb852;
#   color: black;
# }
# #T_696ee_row15_col2, #T_696ee_row22_col4 {
#   background-color: #fc5b2e;
#   color: black;
# }
# #T_696ee_row15_col3, #T_696ee_row27_col4 {
#   background-color: #fc5d2e;
#   color: black;
# }
# #T_696ee_row15_col5 {
#   background-color: #fd903d;
#   color: black;
# }
# #T_696ee_row15_col6, #T_696ee_row28_col6 {
#   background-color: #fd953f;
#   color: black;
# }
# #T_696ee_row16_col2, #T_696ee_row34_col4, #T_696ee_row44_col5 {
#   background-color: #e0181d;
#   color: black;
# }
# #T_696ee_row16_col5, #T_696ee_row41_col5, #T_696ee_row47_col5 {
#   background-color: #f64227;
#   color: black;
# }
# #T_696ee_row16_col6, #T_696ee_row22_col5, #T_696ee_row45_col3 {
#   background-color: #f13624;
#   color: black;
# }
# #T_696ee_row17_col2 {
#   background-color: #c90823;
#   color: black;
# }
# #T_696ee_row17_col3 {
#   background-color: #d10e21;
#   color: black;
# }
# #T_696ee_row17_col4, #T_696ee_row18_col4 {
#   background-color: #ec2c21;
#   color: black;
# }
# #T_696ee_row17_col5 {
#   background-color: #e8241f;
#   color: black;
# }
# #T_696ee_row17_col6, #T_696ee_row22_col3 {
#   background-color: #e7231e;
#   color: black;
# }
# #T_696ee_row18_col2, #T_696ee_row33_col6 {
#   background-color: #cf0c21;
#   color: black;
# }
# #T_696ee_row18_col3, #T_696ee_row26_col5, #T_696ee_row46_col5 {
#   background-color: #d30f20;
#   color: black;
# }
# #T_696ee_row18_col5 {
#   background-color: #e92720;
#   color: black;
# }
# #T_696ee_row18_col6, #T_696ee_row44_col2 {
#   background-color: #ed2e21;
#   color: black;
# }
# #T_696ee_row19_col2 {
#   background-color: #ee3122;
#   color: black;
# }
# #T_696ee_row21_col5, #T_696ee_row21_col6 {
#   background-color: #fd913e;
#   color: black;
# }
# #T_696ee_row22_col2 {
#   background-color: #e2191c;
#   color: black;
# }
# #T_696ee_row22_col6 {
#   background-color: #ea2920;
#   color: black;
# }
# #T_696ee_row23_col2, #T_696ee_row25_col5, #T_696ee_row37_col2 {
#   background-color: #b60026;
#   color: black;
# }
# #T_696ee_row23_col3, #T_696ee_row25_col4 {
#   background-color: #c50624;
#   color: black;
# }
# #T_696ee_row23_col4 {
#   background-color: #db141e;
#   color: black;
# }
# #T_696ee_row23_col5, #T_696ee_row45_col5, #T_696ee_row45_col6 {
#   background-color: #c70723;
#   color: black;
# }
# #T_696ee_row23_col6, #T_696ee_row33_col5 {
#   background-color: #b20026;
#   color: black;
# }
# #T_696ee_row24_col2, #T_696ee_row30_col5 {
#   background-color: #a10026;
#   color: black;
# }
# #T_696ee_row24_col3 {
#   background-color: #b40026;
#   color: black;
# }
# #T_696ee_row24_col4, #T_696ee_row38_col3, #T_696ee_row40_col4 {
#   background-color: #c30424;
#   color: black;
# }
# #T_696ee_row24_col5, #T_696ee_row37_col6 {
#   background-color: #ae0026;
#   color: black;
# }
# #T_696ee_row24_col6 {
#   background-color: #950026;
#   color: black;
# }
# #T_696ee_row25_col2, #T_696ee_row39_col6 {
#   background-color: #bb0026;
#   color: black;
# }
# #T_696ee_row25_col3, #T_696ee_row29_col2 {
#   background-color: #bd0026;
#   color: black;
# }
# #T_696ee_row25

# %% [markdown]
# #### 05.4 - Heat stress maps of warmest day and hour

# %% [markdown]
# Function defining the heat indices

# %%
def calculate_humidex(Ta_k, Td_k):
    """
    Calcola l'Humidex in °C usando la formula di Masterson/Chin.
    Parametri:
      - Ta_k: temperatura dell'aria in Kelvin
      - Td_k: temperatura di rugiada in Kelvin
    Ritorna:
      - Humidex in °C
    """
    # Conversione in °C
    Ta_c = Ta_k - 273.15
    Td_c = Td_k - 273.15

    # Evita valori troppo bassi per Td
    Td_c = np.maximum(Td_c, -73.15)  # ~200 K

    # Calcolo della pressione di vapore (e) in hPa
    exponent = 5417.7530 * ((1.0 / 273.16) - (1.0 / (Td_c + 273.16)))
    e = 6.11 * np.exp(exponent)

    # Formula Humidex
    humidex_c = Ta_c + 0.5555 * (e - 10.0)
    return humidex_c


def calculate_relative_humidity(Ta_c, Td_c):
    """
    Calcola l'umidità relativa in %,
    assumendo Ta_c e Td_c in °C.
    """
    RH = 100.0 * np.exp((17.625 * Td_c) / (243.04 + Td_c)
                        - (17.625 * Ta_c) / (243.04 + Ta_c))
    return RH


def calculate_wbt(Ta_c, RH):
    """
    Calcola la Wet-Bulb Temperature (WBT) in °C (formula semplificata di Stull).
    Parametri:
      - Ta_c: temperatura in °C
      - RH: umidità relativa in %
    """
    WBT_c = (Ta_c * np.arctan(0.151977 * np.sqrt(RH + 8.313659))
             + np.arctan(Ta_c + RH)
             - np.arctan(RH - 1.676331)
             + 0.00391838 * RH**1.5 * np.arctan(0.023101 * RH)
             - 4.686035)
    return WBT_c


def calculate_wbgt(Ta_c, WBT_c):
    """
    Calcola WBGT in °C con la formula semplificata:
      WBGT = 0.7 * WBT + 0.3 * Ta
    Parametri:
      - Ta_c: temperatura in °C
      - WBT_c: Wet-Bulb Temperature in °C
    """
    WBGT_c = 0.7 * WBT_c + 0.3 * Ta_c
    return WBGT_c


def calculate_lethal_heat_stress_index(WBT_c, RH):
    """
    Calcola Lethal Heat Stress Index (Ls) in °C con la formula:
      Ls = WBT + 4.5 * (1 - (RH/100)^2)
    Parametri:
      - WBT_c: Wet-Bulb Temperature in °C
      - RH: umidità relativa in %
    """
    Ls_c = WBT_c + 4.5 * (1.0 - (RH / 100.0)**2)
    return Ls_c


def calculate_utci(Ta_c, RH):
    """
    Calcola una versione semplificata di UTCI in °C,
    Parametri:
      - Ta_c: temperatura in °C
      - RH: umidità relativa in %
    """
    # Pressione di vapore approssimata
    pa = RH / 100.0 * 6.105 * np.exp(17.27 * Ta_c / (237.7 + Ta_c))

    # Formula semplificata
    UTCI_c = (Ta_c
              + 0.607562
              + 0.022771 * Ta_c
              - 0.003578 * RH
              - 0.000119 * Ta_c * RH)
    return UTCI_c

# %% [markdown]
# Map creation displying the heat indices for warmest hour and day of the identyfied heatwaves

# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import contextily as ctx
from pyproj import Transformer
from matplotlib.lines import Line2D
from matplotlib.patches import Rectangle

# === PARAMETRI ===
selected_date = "2017-08-03"
selected_hour = 14

# === CARICAMENTO DATI ===
ds_temp = xr.open_dataset("C:/Users/andre/OneDrive/Desktop/Datasets_Geoinfprj/Enlarged_datasets/2m_air_temp/air_temperature_era5-81_23.nc")
ds_dew = xr.open_dataset("C:/Users/andre/OneDrive/Desktop/Datasets_Geoinfprj/Enlarged_datasets/dew_point_temp/dew_point_temp_81_23.nc")
ds_temp["time"] = pd.to_datetime(ds_temp["time"].values)
ds_dew["time"] = pd.to_datetime(ds_dew["time"].values)

timestamp = pd.Timestamp(f"{selected_date} {selected_hour:02d}:00")
T_k = ds_temp["T_2M"].sel(time=timestamp)
Td_k = ds_dew["TD_2M"].sel(time=timestamp)
Td_k = Td_k.where(Td_k > 243.15).interpolate_na(dim="rlat", method="linear").interpolate_na(dim="rlon", method="linear")

# === CALCOLO INDICI ===
T_c = T_k - 273.15
Td_c = Td_k - 273.15
RH = calculate_relative_humidity(T_c, Td_c)
humidex = calculate_humidex(T_k, Td_k)
wbt = calculate_wbt(T_c, RH)
wbgt = calculate_wbgt(T_c, wbt)
lhs = calculate_lethal_heat_stress_index(wbt, RH)
utci = calculate_utci(T_c, RH)

# === SOGHIE DI PERICOLOSITÀ ===
thresholds = {
    "Humidex (°C)": 45,
    "WBGT (°C)": 30,
    "Lethal Heat Stress Index (°C)": 27,
    "UTCI (°C)": 46
}

# === PARAMETRI DI STILE E PATH ===
title_fontsize = 22
map_title_fontsize = 17
colorbar_labelsize = 13

# === FUNZIONE DI PLOT MULTIPLO CON SOGLIE ===
def plot_4maps_with_thresholds(datasets, titles, cmaps, thresholds, alpha=0.6):
    fig, axs = plt.subplots(2, 2, figsize=(15, 17))
    plt.suptitle(f"Heat stress indices threshold exceedance in {selected_date} at {selected_hour}:00",
                 fontsize=title_fontsize, fontweight="bold", y=1.0)

    lat = ds_temp["lat"].values
    lon = ds_temp["lon"].values
    lon1d = lon[0, :] if lon.ndim == 2 else lon
    lat1d = lat[:, 0] if lat.ndim == 2 else lat

    transformer = Transformer.from_crs("EPSG:4326", "EPSG:3857", always_xy=True)
    lon_mesh, lat_mesh = np.meshgrid(lon1d, lat1d)
    x_mesh, y_mesh = transformer.transform(lon_mesh, lat_mesh)

    axs = axs.flatten()

    for i, (data, title, cmap) in enumerate(zip(datasets, titles, cmaps)):
        ax = axs[i]
        ax.set_xlim(x_mesh.min(), x_mesh.max())
        ax.set_ylim(y_mesh.min(), y_mesh.max())
        ctx.add_basemap(ax, crs="EPSG:3857", source=ctx.providers.OpenStreetMap.Mapnik, attribution=False)

        im = ax.imshow(data.values, extent=[x_mesh.min(), x_mesh.max(), y_mesh.min(), y_mesh.max()],
                       origin='lower', cmap=cmap, alpha=alpha)
        ax.set_title(title, fontsize=map_title_fontsize, fontweight='bold')
        ax.axis("off")

        # === Colorbar ===
        cbar = plt.colorbar(im, ax=ax, orientation="horizontal", pad=0.02)
        cbar.ax.tick_params(labelsize=colorbar_labelsize)

        # === Calcolo threshold
        threshold = thresholds.get(title, None)
        if threshold is not None:
            cbar.ax.axvline(x=threshold, color="black", linestyle="--", linewidth=1.5)

            mask = data.values > threshold
            ax.contour(x_mesh, y_mesh, mask.astype(int), levels=[0.5], colors='black',
                       linewidths=1.2, linestyles='solid')

            line_element = Line2D([0], [0], color="black", linestyle="--", linewidth=2,
                                  label=f"Threshold for {title}")
            rect_element = Rectangle((0, 0), 1, 1, facecolor="none", edgecolor="black", linewidth=1.5,
                                     label="Over the danger threshold")
            ax.legend(handles=[line_element, rect_element],
                      loc="lower center", bbox_to_anchor=(0.5, -0.18),
                      ncol=2, fontsize=11, frameon=False,
                      handlelength=2.5, handletextpad=0.8)

    plt.tight_layout()
    return fig

# === ESECUZIONE ===
fig = plot_4maps_with_thresholds(
    datasets=[humidex, wbgt, lhs, utci],
    titles=["Humidex (°C)", "WBGT (°C)", "Lethal Heat Stress Index (°C)", "UTCI (°C)"],
    cmaps=["plasma", "viridis", "coolwarm", "cividis"],
    thresholds=thresholds
)

# === ESPORTAZIONE FIGURA ===
output_path = rf"C:\Users\andre\OneDrive - Politecnico di Milano\Tesi_di_laurea\elab\04_Outputs\Heat_stress_indices_exceedance__{selected_date}_{selected_hour:02d}.png"  # <-- cambia con la tua directory preferita
plt.savefig(output_path, dpi=300, bbox_inches="tight")
plt.show()
